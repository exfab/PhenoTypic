# %% [markdown]
# # How To: Fit Logistic Growth Models
#
# Fit logistic growth curves to time-series colony measurements and extract
# kinetic parameters (growth rate, carrying capacity, lag time) using
# `LogGrowthModel`.

# %%
from phenotypic.data import load_meas
from phenotypic.analysis import LogGrowthModel

# %%
df = load_meas()
df.head()
# Out:
#   Metadata_Condition Metadata_Media  Metadata_Set  Metadata_Replicate  \
# 0                30C              S             3                   4
# 1                30C              S             3                   5
# 2                30C              S             3                   6
# 3                30C              S             3                  12
# 4                30C              S             3                   8
#
#    Metadata_Time Metadata_Strain Metadata_FileName  Object_Label  \
# 0             24        CBS11445        30C_2_3S_4            14
# 1             24        CBS11445        30C_2_3S_5            14
# 2             24        CBS11445        30C_2_3S_6            13
# 3             24        CBS11445       30C_2_3S_12            16
# 4             24        CBS11445        30C_2_3S_8            14
#
#    Bbox_CenterRR  Bbox_CenterCC  ...  \
# 0     263.025755     327.103517  ...
# 1     309.120466     291.332736  ...
# 2     312.525658     262.907288  ...
# 3     296.079598     305.151655  ...
# 4     318.208931     260.158426  ...
#
#    TextureGray_InfoCorrelation1-deg135-scale04  \
# 0                                    -0.033962
# 1                                    -0.035568
# 2                                    -0.068525
# 3                                    -0.057264
# 4                                    -0.034110
#
#    TextureGray_InfoCorrelation2-deg000-scale04  \
# 0                                     0.523065
# 1                                     0.605276
# 2                                     0.733840
# 3                                     0.715456
# 4                                     0.589887
#
#    TextureGray_InfoCorrelation2-deg045-scale04  \
# 0                                     0.263252
# 1                                     0.243759
# 2                                     0.519368
# 3                                     0.470510
# 4                                     0.358457
#
#    TextureGray_InfoCorrelation2-deg090-scale04  \
# 0                                     0.538240
# 1                                     0.563349
# 2                                     0.658842
# 3                                     0.672158
# 4                                     0.596423
#
#    TextureGray_InfoCorrelation2-deg135-scale04  Metadata_StrainID  \
# 0                                     0.318621                220
# 1                                     0.376115                220
# 2                                     0.497267                220
# 3                                     0.475346                220
# 4                                     0.342946                220
#
#    TextureGray_HaralickVariance-avg-scale04  \
# 0                                  0.662881
# 1                                  1.373371
# 2                                  1.298390
# 3                                  1.870195
# 4                                  1.067527
#
#    CorrectedCarryingCapacity_Intensity  CorrectedCarryingCapacity_Area  \
# 0                          1629.588639                     4183.333333
# 1                          1433.869174                     3225.333333
# 2                          1206.170181                     2984.666667
# 3                          1279.117711                     3074.666667
# 4                          1244.967859                     2988.333333
#
#    Metadata_Dataset
# 0             S 30C
# 1             S 30C
# 2             S 30C
# 3             S 30C
# 4             S 30C
#
# [5 rows x 245 columns]

# %% [markdown]
# ## Fit the Model
#
# Specify the target measurement column, grouping structure, and time
# label. The model fits a logistic curve to each group independently.

# %%
model = LogGrowthModel(
    on="Shape_Area",
    groupby=["Metadata_Strain"],
    time_label="Metadata_Time",
    agg_func="mean",
)

# %%
results = model.analyze(df)
results
# Out:
#   Metadata_Strain  LogGrowthModel_Area_r  LogGrowthModel_Area_K  \
# 0        CBS11445               0.128296            2774.486145
# 1         CBS1553               0.096670            2461.589556
# 2         CBS1554               0.049705            2549.056960
#
#    LogGrowthModel_Area_N0  LogGrowthModel_Area_µmax  LogGrowthModel_Area_Kmax  \
# 0              361.146893                 88.989208               3018.454545
# 1              268.039042                 59.490509               2472.666667
# 2             1027.927953                 31.675310               2552.125000
#
#    ModelMetrics_Area_MAE  ModelMetrics_Area_MSE  ModelMetrics_Area_RMSE  \
# 0             149.156592           37500.692716              193.650956
# 1             111.983444           41337.150373              203.315396
# 2              50.849749            4101.485325               64.042840
#
#    ModelMetrics_Area_R2  ModelMetrics_Area_OptimizerLoss  \
# 0              0.628794                      1235.513466
# 1              0.348866                       915.756366
# 2              0.953202                      1411.496844
#
#    ModelMetrics_Area_OptimizerStatus  ModelMetrics_Area_NumSamples  \
# 0                                  3                             5
# 1                                  2                             5
# 2                                  3                             5
#
#    LogGrowthModel_Area_lambda  LogGrowthModel_Area_beta
# 0                         1.2                         2
# 1                         1.2                         2
# 2                         1.2                         2

# %% [markdown]
# The results DataFrame contains fitted parameters for each group:
# growth rate, carrying capacity (K), and lag time. Use these to
# compare strain fitness across experimental conditions.
