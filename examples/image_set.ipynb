# %%
from phenotypic import data
from phenotypic import ImageSet, GridImage
import tempfile

lactose_images = data.load_lactose_series()[:2]
lactose_images = [GridImage(x, name=idx) for idx, x in enumerate(lactose_images)]
image_set = ImageSet(name='test', outpath=None, overwrite=True)
image_set.import_images(lactose_images)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[4], line 7
#       5 lactose_images = data.load_lactose_series()[:2]
#       6 lactose_images = [GridImage(x, name=idx) for idx, x in enumerate(lactose_images)]
# ----> 7 image_set = ImageSet(name='test', outpath=None, overwrite=True)
#       8 image_set.import_images(lactose_images)
#
# File ~/Projects/PhenoTypic/src/phenotypic/core/_image_set_parts/_image_set_measurements.py:47, in ImageSetMeasurements.__init__(self, name, outpath, imtype, imparams, default_mode, overwrite)
#      21 def __init__(self,
#      22              name: str,
#      23              outpath: PathLike | str | None = None,
#    (...)     26              default_mode: Literal['temp', 'cwd'] = 'temp',
#      27              overwrite: bool = False, ):
#      28     """
#      29     Initializes the instance with the specified parameters.
#      30
#    (...)     45             data at the output path. Defaults to False.
#      46     """
# ---> 47     super().__init__(name=name, outpath=outpath, imtype=imtype, imparams=imparams, default_mode=default_mode,
#      48                      overwrite=overwrite)
#      49     self._measurement_accessor = SetMeasurementAccessor(self)
#
# File ~/Projects/PhenoTypic/src/phenotypic/core/_image_set_parts/_image_set_status.py:34, in ImageSetStatus.__init__(self, name, outpath, imtype, imparams, default_mode, overwrite)
#      31 super().__init__(name=name, outpath=outpath, imtype=imtype,
#      32                  imparams=imparams, default_mode=default_mode, overwrite=overwrite)
#      33 if overwrite:
# ---> 34     self.reset_status()
#
# File ~/Projects/PhenoTypic/src/phenotypic/core/_image_set_parts/_image_set_status.py:54, in ImageSetStatus.reset_status(self, image_names)
#      37 """
#      38 Resets the status attributes of specified image names or all available image
#      39 names within the HDF5 file. This method updates the status attributes to an
#    (...)     51         The type must be a string, list of strings, or None.
#      52 """
#      53 if image_names is None:
# ---> 54     image_names = self.get_image_names()
#      55 else:
#      56     assert isinstance(image_names, (str, list)), 'image_names must be a list of image names or a str.'
#
# File ~/Projects/PhenoTypic/src/phenotypic/core/_image_set_parts/_image_set_core.py:207, in ImageSetCore.get_image_names(self)
#     196 def get_image_names(self) -> List[str]:
#     197     """
#     198     Retrieves the names of all images stored within the specified HDF5 group.
#     199
#    (...)    205         List[str]: A list of image names present in the specified HDF5 group.
#     206     """
# --> 207     with self.hdf_.reader() as reader:
#     208         set_group = self.hdf_.get_data_group(reader)
#     209         names = list(set_group.keys())
#
# File ~/Projects/PhenoTypic/src/phenotypic/tools/hdf_.py:268, in HDF.reader(self)
#     267 def reader(self) -> h5py.File:
# --> 268     return h5py.File(self.filepath, 'r', libver='latest', swmr=False)
#
# File ~/Projects/PhenoTypic/.venv/lib/python3.11/site-packages/h5py/_hl/files.py:566, in File.__init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, fs_page_size, page_buf_size, min_meta_keep, min_raw_keep, locking, alignment_threshold, alignment_interval, meta_block_size, track_times, **kwds)
#     557     fapl = make_fapl(driver, libver, rdcc_nslots, rdcc_nbytes, rdcc_w0,
#     558                      locking, page_buf_size, min_meta_keep, min_raw_keep,
#     559                      alignment_threshold=alignment_threshold,
#     560                      alignment_interval=alignment_interval,
#     561                      meta_block_size=meta_block_size,
#     562                      **kwds)
#     563     fcpl = make_fcpl(track_order=track_order, track_times=track_times,
#     564                      fs_strategy=fs_strategy, fs_persist=fs_persist,
#     565                      fs_threshold=fs_threshold, fs_page_size=fs_page_size)
# --> 566     fid = make_fid(name, mode, userblock_size, fapl, fcpl, swmr=swmr)
#     568 if isinstance(libver, tuple):
#     569     self._libver = libver
#
# File ~/Projects/PhenoTypic/.venv/lib/python3.11/site-packages/h5py/_hl/files.py:241, in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     239     if swmr and swmr_support:
#     240         flags |= h5f.ACC_SWMR_READ
# --> 241     fid = h5f.open(name, flags, fapl=fapl)
#     242 elif mode == 'r+':
#     243     fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py/h5f.pyx:104, in h5py.h5f.open()
#
# OSError: Unable to synchronously open file (file signature not found)

# %%
from phenotypic import ImageSet, ImagePipeline
from phenotypic.enhance import CLAHE
from phenotypic.measure import MeasureShape, MeasureIntensity
from phenotypic.detection import OtsuDetector
from phenotypic.objedit import MaskOpener
import skimage.morphology as morph
from pathlib import Path
from phenotypic import GridImage

pipeline = ImagePipeline(
        ops=[CLAHE(), OtsuDetector(),
             # MaskOpener(footprint=morph.diamond(radius=3))
             ],
        meas=[
            MeasureShape()
        ]
)
meas = pipeline.apply_and_measure(image_set)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 18
#       8 from phenotypic import GridImage
#      10 pipeline = ImagePipeline(
#      11     ops=[CLAHE(), OtsuDetector(),
#      12          # MaskOpener(footprint=morph.diamond(radius=3))
#    (...)     16     ]
#      17 )
# ---> 18 meas = pipeline.apply_and_measure(image_set)
#
# File ~/Projects/PhenoTypic/src/phenotypic/core/_pipeline_parts/_image_pipeline_batch.py:124, in ImagePipelineBatch.apply_and_measure(self, image, inplace, reset, include_metadata)
#     117     return super().apply_and_measure(
#     118             image=image,
#     119             inplace=inplace,
#     120             reset=reset,
#     121             include_metadata=include_metadata,
#     122     )
#     123 elif isinstance(image, pt.ImageSet):
# --> 124     return self._coordinator(image,
#     125                              mode=PipelineMode.APPLY_MEASURE,
#     126                              num_workers=self.num_workers, reset=reset)
#     127 else:
#     128     raise TypeError("image must be Image or ImageSet")
#
# File ~/Projects/PhenoTypic/src/phenotypic/core/_pipeline_parts/_image_pipeline_batch.py:150, in ImagePipelineBatch._coordinator(self, image_set, mode, num_workers, reset)
#     148 if mode in {PipelineMode.MEASURE, PipelineMode.APPLY_MEASURE}:
#     149     logger.info(f"allocating measurement datasets for {image_set.name}")
# --> 150     self._allocate_measurement_datasets(image_set)
#     151     logger.debug(f'allocation done. ready to process images.')
#     152 """
#     153 Step 2: spawn writer, producer, and worker processes.
#     154     - single producer will wait till memory is available then enqueue image names to worker queue for processing
#    (...)    166
#     167 """
#
# File ~/Projects/PhenoTypic/src/phenotypic/core/_pipeline_parts/_image_pipeline_batch.py:286, in ImagePipelineBatch._allocate_measurement_datasets(self, imageset)
#     282         logger.debug(
#     283                 f'Allocating statuses for {image_name}: {status_group.attrs.keys()} -> {status_group.attrs.values()}')
#     284         meas_group = imageset.hdf_.get_image_measurement_subgroup(handle=writer, image_name=image_name)
# --> 286         imageset.hdf_.preallocate_frame_layout(
#     287                 group=meas_group,
#     288                 dataframe=sample_meas,
#     289                 chunks=25,
#     290                 compression='gzip',
#     291                 preallocate=100,
#     292                 string_fixed_length=100,
#     293                 require_swmr=False,
#     294         )
#     295 return
#
# File ~/Projects/PhenoTypic/src/phenotypic/tools/hdf_.py:1483, in HDF.preallocate_frame_layout(group, dataframe, chunks, compression, preallocate, string_fixed_length, require_swmr)
#    1480 group.attrs["len"] = 0
#    1482 # Preallocate index layout
# -> 1483 index_group = group.create_group("index")
#    1484 # Create a dummy series with string values to match the schema
#    1485 dummy_series = pd.Series([], dtype=str, index=dataframe.index[:0], name="__index__")
#
# File ~/Projects/PhenoTypic/.venv/lib/python3.11/site-packages/h5py/_hl/group.py:71, in Group.create_group(self, name, track_order, track_times)
#      69 else:
#      70     raise TypeError("track_times must be either True, False, or None")
# ---> 71 gid = h5g.create(self.id, name, lcpl=lcpl, gcpl=gcpl)
#      72 return Group(gid)
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py/h5g.pyx:173, in h5py.h5g.create()
#
# ValueError: Unable to synchronously create group (name already exists)

# %%
image_set.get_measurement()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 image_set.get_measurement()
#
# File ~/Projects/PhenoTypic/src/phenotypic/core/_image_set_parts/_image_set_measurements.py:87, in ImageSetMeasurements.get_measurement(self, image_names)
#      84 logger.debug(f'Image group status attrs for "{name}": {status_subgroup.attrs.keys()}')
#      85 # TODO: Finish implementing measurement aggregator
#      86 # Validate that the measurements were sucessfully taken by the pipeline
# ---> 87 if ((status_subgroup.attrs[PIPE_STATUS.PROCESSED])
#      88         and (status_subgroup.attrs[PIPE_STATUS.MEASURED])
#      89         and (measurement_key in image_group)):
#      90     df = self.hdf_.load_frame(
#      91             group=self.hdf_.get_image_measurement_subgroup(handle=handle, image_name=name), )
#      93     prot_metadata_group = self.hdf_.get_protected_metadata_subgroup(handle=handle, image_name=name)
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File ~/Projects/PhenoTypic/.venv/lib/python3.11/site-packages/h5py/_hl/attrs.py:55, in AttributeManager.__getitem__(self, name)
#      51 @with_phil
#      52 def __getitem__(self, name):
#      53     """ Read the value of an attribute.
#      54     """
# ---> 55     attr = h5a.open(self._id, self._e(name))
#      56     shape = attr.shape
#      58     # shape is None for empty dataspaces
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py/h5a.pyx:79, in h5py.h5a.open()
#
# KeyError: "Unable to synchronously open attribute (can't locate attribute: 'Status_Processed')"
