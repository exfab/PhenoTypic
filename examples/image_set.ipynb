# %%
from phenotypic import data
from phenotypic import ImageSet, GridImage
import tempfile

lactose_images = data.load_lactose_series()[:2]
lactose_images = [GridImage(x, name=idx) for idx, x in enumerate(lactose_images)]
image_set = ImageSet(name='test', outpath=None, overwrite=True)
image_set.import_images(lactose_images)

# %%
from phenotypic import ImageSet, ImagePipeline
from phenotypic.enhance import CLAHE
from phenotypic.measure import MeasureShape, MeasureIntensity
from phenotypic.detect import OtsuDetector
from phenotypic.objedit import MaskOpener
import skimage.morphology as morph
from pathlib import Path
from phenotypic import GridImage

import logging

# Python
logging.getLogger("ImagePipeline").setLevel(logging.DEBUG)
logging.getLogger("ImagePipeline.coordinator").setLevel(logging.DEBUG)
logging.getLogger("ImagePipeline.parallel").setLevel(logging.DEBUG)
logging.getLogger("ImagePipeline.producer").setLevel(logging.DEBUG)
logging.getLogger("ImagePipeline.writer").setLevel(logging.DEBUG)
logging.getLogger("ImagePipeline._worker()").setLevel(logging.DEBUG)
pipeline = ImagePipeline(
        ops=[CLAHE(), OtsuDetector(),
             # MaskOpener(footprint=morph.diamond(radius=3))
             ],
        meas=[
            MeasureShape()
        ]
)
meas = pipeline.apply_and_measure(image_set)
# Out:
# Exception in thread Thread-5 (_writer):
# Traceback (most recent call last):
#   File "/Users/alex/.local/share/uv/python/cpython-3.11.13-macos-aarch64-none/lib/python3.11/threading.py", line 1045, in _bootstrap_inner
#     self.run()
#   File "/Users/alex/Projects/PhenoTypic/.venv/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 788, in run_closure
#     _threading_Thread_run(self)
#   File "/Users/alex/.local/share/uv/python/cpython-3.11.13-macos-aarch64-none/lib/python3.11/threading.py", line 982, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/alex/Projects/PhenoTypic/src/phenotypic/core/_pipeline_parts/_image_pipeline_batch.py", line 389, in _writer
#     status_group = image_set.hdf_.get_status_subgroup(handle=writer, image_name=image_name)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/alex/Projects/PhenoTypic/src/phenotypic/tools/hdf_.py", line 369, in get_status_subgroup
#     return self.get_group(handle, posixpath.join(self.set_data_posix, image_name, self.IMAGE_STATUS_SUBGROUP_KEY))
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen posixpath>", line 90, in join
#   File "<frozen genericpath>", line 152, in _check_arg_types
# TypeError: join() argument must be str, bytes, or os.PathLike object, not 'int'
# Process SpawnProcess-3:
# Traceback (most recent call last):
#   File "/Users/alex/.local/share/uv/python/cpython-3.11.13-macos-aarch64-none/lib/python3.11/multiprocessing/process.py", line 317, in _bootstrap
#     util._exit_function()
#   File "/Users/alex/.local/share/uv/python/cpython-3.11.13-macos-aarch64-none/lib/python3.11/multiprocessing/util.py", line 363, in _exit_function
#     _run_finalizers()
#   File "/Users/alex/.local/share/uv/python/cpython-3.11.13-macos-aarch64-none/lib/python3.11/multiprocessing/util.py", line 303, in _run_finalizers
#     finalizer()
#   File "/Users/alex/.local/share/uv/python/cpython-3.11.13-macos-aarch64-none/lib/python3.11/multiprocessing/util.py", line 227, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/alex/.local/share/uv/python/cpython-3.11.13-macos-aarch64-none/lib/python3.11/multiprocessing/queues.py", line 199, in _finalize_join
#     thread.join()
#   File "/Users/alex/.local/share/uv/python/cpython-3.11.13-macos-aarch64-none/lib/python3.11/threading.py", line 1119, in join
#     self._wait_for_tstate_lock()
#   File "/Users/alex/.local/share/uv/python/cpython-3.11.13-macos-aarch64-none/lib/python3.11/threading.py", line 1139, in _wait_for_tstate_lock
#     if lock.acquire(block, timeout):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 27
#      18 logging.getLogger("ImagePipeline._worker()").setLevel(logging.DEBUG)
#      19 pipeline = ImagePipeline(
#      20         ops=[CLAHE(), OtsuDetector(),
#      21              # MaskOpener(footprint=morph.diamond(radius=3))
#    (...)     25         ]
#      26 )
# ---> 27 meas = pipeline.apply_and_measure(image_set)
#
# File ~/Projects/PhenoTypic/src/phenotypic/core/_pipeline_parts/_image_pipeline_batch.py:125, in ImagePipelineBatch.apply_and_measure(self, image, inplace, reset, include_metadata)
#     118     return super().apply_and_measure(
#     119             image=image,
#     120             inplace=inplace,
#     121             reset=reset,
#     122             include_metadata=include_metadata,
#     123     )
#     124 elif isinstance(image, pt.ImageSet):
# --> 125     return self._coordinator(image,
#     126                              mode=PipelineMode.APPLY_MEASURE,
#     127                              num_workers=self.num_workers, reset=reset)
#     128 else:
#     129     raise TypeError("image must be Image or ImageSet")
#
# File ~/Projects/PhenoTypic/src/phenotypic/core/_pipeline_parts/_image_pipeline_batch.py:241, in ImagePipelineBatch._coordinator(self, image_set, mode, num_workers, reset)
#     238 for w in workers: w.start()
#     239 logger.info('All worker processes started')
# --> 241 for w in workers: w.join()
#     242 logger.info(f'All worker processes completed, joining writer...')
#     244 thread_stop_event.set()
#
# File ~/.local/share/uv/python/cpython-3.11.13-macos-aarch64-none/lib/python3.11/multiprocessing/process.py:149, in BaseProcess.join(self, timeout)
#     147 assert self._parent_pid == os.getpid(), 'can only join a child process'
#     148 assert self._popen is not None, 'can only join a started process'
# --> 149 res = self._popen.wait(timeout)
#     150 if res is not None:
#     151     _children.discard(self)
#
# File ~/.local/share/uv/python/cpython-3.11.13-macos-aarch64-none/lib/python3.11/multiprocessing/popen_fork.py:43, in Popen.wait(self, timeout)
#      41             return None
#      42     # This shouldn't block if wait() returned successfully.
# ---> 43     return self.poll(os.WNOHANG if timeout == 0.0 else 0)
#      44 return self.returncode
#
# File ~/.local/share/uv/python/cpython-3.11.13-macos-aarch64-none/lib/python3.11/multiprocessing/popen_fork.py:27, in Popen.poll(self, flag)
#      25 if self.returncode is None:
#      26     try:
# ---> 27         pid, sts = os.waitpid(self.pid, flag)
#      28     except OSError:
#      29         # Child process not yet created. See #1731717
#      30         # e.errno == errno.ECHILD == 10
#      31         return None
#
# KeyboardInterrupt:

# %%
image_set.get_measurement()
# Out:
# Empty DataFrame
# Columns: []
# Index: []
