# %% [markdown]
# # How To: Measure Colony Size and Intensity
#
# Extract area, perimeter, circularity, and intensity statistics from
# detected colonies using `MeasureSize`, `MeasureShape`, and
# `MeasureIntensity`.

# %%
import phenotypic as pht
from phenotypic.data import load_yeast_plate
from phenotypic.enhance import GaussianBlur, CLAHE
from phenotypic.detect import OtsuDetector
from phenotypic.measure import MeasureSize, MeasureShape, MeasureIntensity

# %%
pipeline = pht.ImagePipeline(
    ops=[GaussianBlur(sigma=2.0), CLAHE(clip_limit=0.01), OtsuDetector()],
    meas=[MeasureSize(), MeasureShape(), MeasureIntensity()],
)
df = pipeline.apply_and_measure(load_yeast_plate())

# %% [markdown]
# ## Size Metrics

# %%
df[["Area", "IntegratedIntensity"]].describe()

# %% [markdown]
# ## Shape Metrics

# %%
df[["Circularity", "Solidity", "Eccentricity"]].describe()

# %% [markdown]
# ## Intensity Metrics

# %%
df[["MeanIntensity", "MedianIntensity", "StandardDeviationIntensity"]].describe()

# %% [markdown]
# The DataFrame has one row per colony. Filter, sort, and group using
# standard pandas operations to answer biological questions.
